# %%
import config
import pandas as pd

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.Client_ID,
                                                           client_secret= config.Client_Secret))

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
hits1=get_playlist_tracks("spotify", "37i9dQZF1DX0kbJZpiYdZl")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
list_of_audio_features=[]
for item in range(0,49):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(hits1[item]["track"]["id"])[0])

# %%
hits1=pd.DataFrame(list_of_audio_features)    
hits1['label']='hits'

# %%
hits2=get_playlist_tracks("spotify", "6cxs2lOOJje0WDqyVE6LbX")

# %%
list_of_audio_features=[]
for item in range(0,352):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(hits2[item]["track"]["id"])[0])

# %%
hits2=pd.DataFrame(list_of_audio_features)    
hits2['label']='hits'

# %%
rock=get_playlist_tracks("spotify", "7anzGe05Fe2CC3wCLnLU4f")

# %%
list_of_audio_features=[]
for item in range(0,400):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(rock[item]["track"]["id"])[0])

# %%
rock=pd.DataFrame(list_of_audio_features)    
rock['label']='rock'

# %%
techno=get_playlist_tracks("spotify", "18vUeZ9BdtMRNV6gI8RnR6")

# %%
list_of_audio_features=[]
for item in range(0,149):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(techno[item]["track"]["id"])[0])

# %%
techno=pd.DataFrame(list_of_audio_features)    
techno['label']='techno'

# %%
dance=get_playlist_tracks("spotify", "1ADtcUYFISue4ua9pYjo9v")

# %%
list_of_audio_features=[]
for item in range(0,119):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(dance[item]["track"]["id"])[0])

# %%
dance=pd.DataFrame(list_of_audio_features)    
dance['label']='dance'

# %%
rap=get_playlist_tracks("spotify", "4riovLwMCrY3q0Cd4e0Sqp")

# %%
list_of_audio_features=[]
for item in range(0,288):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(rap[item]["track"]["id"])[0])

# %%
rap=pd.DataFrame(list_of_audio_features)    
rap['label']='rap'

# %%
r_n_b=get_playlist_tracks("spotify", "37i9dQZF1DWTbCTQUrf6sj")

list_of_audio_features=[]
for item in range(0,99):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(r_n_b[item]["track"]["id"])[0])
    
r_n_b=pd.DataFrame(list_of_audio_features)    
r_n_b['label']='r_n_b'

# %%
heavy_metal=get_playlist_tracks("spotify", "1yMlpNGEpIVUIilZlrbdS0")

list_of_audio_features=[]
for item in range(0,199):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(heavy_metal[item]["track"]["id"])[0])
    
heavy_metal=pd.DataFrame(list_of_audio_features)    
heavy_metal['label']='heavy_metal'

# %%
popular=get_playlist_tracks("spotify", "5ABHKGoOzxkaa28ttQV9sE")

list_of_audio_features=[]
for item in range(0,99):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(popular[item]["track"]["id"])[0])
    
popular=pd.DataFrame(list_of_audio_features)    
popular['label']='popular'

# %%
eightinighti=get_playlist_tracks("spotify", "2hlsujw9cWHaDG95eXitsm")

list_of_audio_features=[]
for item in range(0,428):
    #print (tracks[item]["track"]["id"])
    list_of_audio_features.append(sp.audio_features(eightinighti[item]["track"]["id"])[0])
    
eightinighti=pd.DataFrame(list_of_audio_features)    
eightinighti['label']='80_90'

# %%
song_d2 = pd.concat([hits1,hits2,rock,techno,dance,rap,r_n_b,classical,popular,eightinighti])
song_d2
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.561   0.520   11    -9.342     0       0.2440       0.05030
# 1           0.637   0.643    4    -6.571     1       0.0519       0.13000
# 2           0.714   0.472    2    -7.375     1       0.0864       0.01300
# 3           0.686   0.507    1    -7.097     1       0.0357       0.62600
# 4           0.838   0.525   10    -3.562     1       0.0665       0.34500
# ..            ...     ...  ...       ...   ...          ...           ...
# 423         0.763   0.405    9   -16.065     1       0.0427       0.60600
# 424         0.566   0.585    9    -7.532     1       0.0320       0.10600
# 425         0.594   0.750    2    -7.216     1       0.0299       0.07570
# 426         0.527   0.923    9    -7.677     1       0.0599       0.00907
# 427         0.708   0.738    4    -9.509     0       0.0422       0.06780
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000002    0.3550    0.424  153.150  audio_features
# 1            0.000002    0.1420    0.533   97.008  audio_features
# 2            0.000005    0.2660    0.238  131.121  audio_features
# 3            0.000075    0.3830    0.690  168.955  audio_features
# 4            0.000002    0.0771    0.884  144.981  audio_features
# ..                ...       ...      ...      ...             ...
# 423          0.124000    0.1030    0.858  158.509  audio_features
# 424          0.000000    0.2300    0.750  126.100  audio_features
# 425          0.000244    0.0593    0.693  122.949  audio_features
# 426          0.000026    0.3410    0.461   97.029  audio_features
# 427          0.092800    0.3540    0.545  160.554  audio_features
#
#                          id                                   uri  \
# 0    1bDbXMyjaUIooNwFE9wn0N  spotify:track:1bDbXMyjaUIooNwFE9wn0N
# 1    0V3wPSX9ygBnCm8psDIegu  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 2    3nqQXoyQOWXiESFLlDF1hG  spotify:track:3nqQXoyQOWXiESFLlDF1hG
# 3    5CM4UuQ9Gnd6K2YyKGPMoK  spotify:track:5CM4UuQ9Gnd6K2YyKGPMoK
# 4    0QHEIqNKsMoOY5urbzN48u  spotify:track:0QHEIqNKsMoOY5urbzN48u
# ..                      ...                                   ...
# 423  2G2KFn0bw18vJakvnJuzsC  spotify:track:2G2KFn0bw18vJakvnJuzsC
# 424  57TaM8GozkJBz90xvQ1xME  spotify:track:57TaM8GozkJBz90xvQ1xME
# 425  1r9QBciQVM1BnW72cQUA4R  spotify:track:1r9QBciQVM1BnW72cQUA4R
# 426  0ykRm2cMP8ku2qRj5UpEsg  spotify:track:0ykRm2cMP8ku2qRj5UpEsg
# 427  4fHug3zCanK33sdvticISi  spotify:track:4fHug3zCanK33sdvticISi
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/1bDbXMyjaUIo...
# 1    https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 2    https://api.spotify.com/v1/tracks/3nqQXoyQOWXi...
# 3    https://api.spotify.com/v1/tracks/5CM4UuQ9Gnd6...
# 4    https://api.spotify.com/v1/tracks/0QHEIqNKsMoO...
# ..                                                 ...
# 423  https://api.spotify.com/v1/tracks/2G2KFn0bw18v...
# 424  https://api.spotify.com/v1/tracks/57TaM8GozkJB...
# 425  https://api.spotify.com/v1/tracks/1r9QBciQVM1B...
# 426  https://api.spotify.com/v1/tracks/0ykRm2cMP8ku...
# 427  https://api.spotify.com/v1/tracks/4fHug3zCanK3...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/1bDb...       239360
# 1    https://api.spotify.com/v1/audio-analysis/0V3w...       200690
# 2    https://api.spotify.com/v1/audio-analysis/3nqQ...       156943
# 3    https://api.spotify.com/v1/audio-analysis/5CM4...       232115
# 4    https://api.spotify.com/v1/audio-analysis/0QHE...       134256
# ..                                                 ...          ...
# 423  https://api.spotify.com/v1/audio-analysis/2G2K...       226093
# 424  https://api.spotify.com/v1/audio-analysis/57Ta...       207173
# 425  https://api.spotify.com/v1/audio-analysis/1r9Q...       245107
# 426  https://api.spotify.com/v1/audio-analysis/0ykR...       212333
# 427  https://api.spotify.com/v1/audio-analysis/4fHu...       300227
#
#      time_signature  label
# 0                 3   hits
# 1                 4   hits
# 2                 4   hits
# 3                 4   hits
# 4                 4   hits
# ..              ...    ...
# 423               4  80_90
# 424               4  80_90
# 425               4  80_90
# 426               4  80_90
# 427               4  80_90
#
# [2132 rows x 19 columns]

# %%
song_d2.to_csv("song_df2.csv")
